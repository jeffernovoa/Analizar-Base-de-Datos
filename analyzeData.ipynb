# %% [markdown]
# # Análisis de Base de Datos de Clientes

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd

df = pd.read_csv('clientes.csv')
columns = df.columns

print("Tamaño de la DB:", df.shape)
print("Columnas de la DB:", df.columns)
print("Tipos de datos:", df.dtypes)
print(df.head())
# Out:
# Tamaño de la DB: (10000, 13)
# Columnas de la DB: Index(['cliente_id', 'contrato_id', 'edad', 'provincia', 'antiguedad_meses',
#        'cuota_mensual', 'canal', 'producto', 'ingresos_mensuales',
#        'incidencias_12m', 'satisfaccion', 'fecha_alta', 'abandono'],
#       dtype='str')
# Tipos de datos: cliente_id                str
# contrato_id               str
# edad                    int64
# provincia                 str
# antiguedad_meses        int64
# cuota_mensual         float64
# canal                     str
# producto                  str
# ingresos_mensuales    float64
# incidencias_12m         int64
# satisfaccion          float64
# fecha_alta                str
# abandono                  str
# dtype: object
#    cliente_id contrato_id  edad  provincia  antiguedad_meses  cuota_mensual  \
# 0  CLI-000052  CTR-000052    42   Valencia                10         100.94
# 1  CLI-001100  CTR-001100    31   Alicante                38          45.75
# ...

# %% [markdown]
# ## 1. Exploración Inicial de Datos
#
# Cargaremos el archivo CSV y examinaremos su estructura, dimensiones, tipos de datos y primeros registros.
